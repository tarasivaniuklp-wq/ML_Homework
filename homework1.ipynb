# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')
print(df.shape[0])
df["fuel_type"].nunique()
df.isnull().sum()[df.isnull().sum()>0]
df.columns
# Out:
# 10000
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
df[df['origin']=='Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
print(df['horsepower'].median())
mode = df['horsepower'].mode()[0]
print(mode)
df['horsepower'] = df['horsepower'].fillna(mode)
print(df['horsepower'].median())
# Out:
# 252.0
# 252.0
# 252.0

# %%
Asia_cars = df[df['origin'] == 'Asia']
target_columns = Asia_cars[['vehicle_weight', 'model_year']]
target_columns = target_columns.head(n=7)
x = np.array(target_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 4
#       1 Asia_cars = df[df['origin'] == 'Asia']
#       2 target_columns = Asia_cars[['vehicle_weight', 'model_year']]
#       3 target_columns = target_columns.head(n=7)
# ----> 4 x = np.array(target_columns)
#
# NameError: name 'np' is not defined
